# %%
from splinter import Browser
from bs4 import BeautifulSoup

# %%
# Mac Users
# # https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
# Windows
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.imdb.com/search/title/?companies=co0144901'
browser.visit(url)

# %%
import time

# %%
title_dict = {}
for x in range(100):
    # HTML object
    html = browser.html
    
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'lxml')
    
    # Retrieve all elements that contain book information
    articles = soup.find_all('div', class_='lister-item-content')

    # Iterate through each book
    for article in articles:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        h3 = article.find('h3')
        title = h3.find('a').text
        
        if "title" in title_dict:
            title_dict["title"].append(title)
        else:
            title_dict["title"] = [title]
            
        try:
            aud_rate = article.find('p')
            rated = aud_rate.find_all('span')[0].text
            
            if "rated" in title_dict:
                title_dict["rated"].append(rated)
            else:
                title_dict["rated"] = [rated]
        except:
            title_dict["rated"].append(None)
            
        try:
            rating_line = article.find('div', class_='ratings-bar')
            rating = rating_line.find('div', class_='inline-block ratings-imdb-rating')['data-value']
            if "rating" in title_dict:
                title_dict["rating"].append(rating)
            else:
                title_dict["rating"] = [rating]
            
        except:
            title_dict["rating"].append(None)
        
        time.sleep(2)
                
        try:
            browser.click_link_by_partial_text('Next')
        except:
            print("Scraping Complete")
            
#         try:
#             aud_rate = article.find('p')
#             rated = aud_rate.find_all('span')[0].text
            
#             if "rated" in title_dict:
#                 title_dict["rated"].append(rated)
#             else:
#                 title_dict["rated"] = [rated]
                
# #         try:
            
            
            
            
            
# #             user_rating = 
        
        
        
        
        
# #         href = link['href']
# #         title = link['title']
# #         print('-----------')
# #         print(title)
# #         print('http://books.toscrape.com/' + href)

#     # Click the 'Next' button on each page
#         try:
#             browser.click_link_by_partial_text('next')
          
#         except:
#             print("Scraping Complete")
# Out:
# C:\Users\rskan\Anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py:493: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,

# %%
print(title_dict)

# %%
import pandas as pd

# %%
df = pd.DataFrame(title_dict)

# %%
df
# Out:
#                                             title  \
# 0                                One in a Billion
# 1                                 The Jungle Book
# 2   Ronny Chieng: Asian Comedian Destroys America
# 3                                   No Estoy Loca
# 4                           Live at the Foxes Den
# 5                                             Amo
# 6          Anthony Jeselnik: Thoughts and Prayers
# 7                                  ¡Ay, mi madre!
# 8                                Tribes Of Europa
# 9                                      Sentinelle
# 10                            Shine On with Reese
# 11                       Revenge of the Pontianak
# 12                                       Hellions
# 13                            Pride and Prejudice
# 14                              Grandma's Wedding
# 15                                 Mujeres Arriba
# 16                                         Misfit
# 17                             My Fellow Citizens
# 18                                 Rodeo & Juliet
# 19                         The Russian Revolution
# 20                                Growing Up Wild
# 21               Trigger Warning with Killer Mike
# 22                                      Bad Blood
# 23                                       Upstarts
# 24                        Iliza: Elder Millennial
# 25                                             Mo
# 26       My Little Pony: Equestria Girls Specials
# 27                                     Der Wixxer
# 28                           Til Death Do Us Part
# 29                     Kevin Hart: Let Me Explain
# 30                       Nightworld: Door of Hell
# 31                  Cricket Fever: Mumbai Indians
# 32              Johan Falk: Organizatsija Karayan
# 33                          The Ollie & Moon Show
# 34                                   The Standups
# 35                                       Sky Rojo
# 36                            Historia de un clan
# 37                  Our Planet: Behind the Scenes
# 38                    Bert Kreischer: Hey Big Boy
# 39                                  Hospital Ship
# 40                         My Dear Prime Minister
# 41                              The Rachel Divide
# 42                        How Sarah Got Her Wings
# 43                                 Desert Dolphin
# 44                      Boss Wants a Happy Ending
# 45                                   SSSS.Gridman
# 46                                         Street
# 47                                         Homies
# 48                       The Mess You Left Behind
# 49            Feminists: What Were They Thinking?
# 50                                 Rick and Morty
# 51                                 Rick and Morty
#
#                              rated rating
# 0                           69 min    6.8
# 1                           11 min    4.7
# 2                            TV-MA    7.4
# 3                            TV-MA    5.5
# 4                        Not Rated    4.9
# 5                            TV-MA    6.4
# 6                            TV-MA    7.8
# 7                            TV-MA    3.8
# 8             \nSci-Fi               None
# 9                           80 min   None
# 10                          30 min    7.6
# 11                          92 min    5.2
# 12                       Not Rated    4.2
# 13    \nDrama, Romance                  7
# 14                          97 min    5.4
# 15                         100 min    3.6
# 16                          86 min    4.4
# 17            \nComedy                7.1
# 18                         Unrated    4.7
# 19                           TV-14    6.6
# 20                               G    7.3
# 21                           TV-MA    6.9
# 22                       Not Rated    4.6
# 23                         112 min    6.6
# 24                           TV-MA    7.2
# 25                       Not Rated    6.5
# 26                            TV-Y    6.3
# 27                          85 min    6.2
# 28  \nSci-Fi, Thriller                6.4
# 29                               R    6.8
# 30                           TV-MA    4.4
# 31                          40 min    7.3
# 32                          97 min    6.6
# 33                          11 min    8.2
# 34                          30 min    6.7
# 35            \nAction               None
# 36                           TV-MA    7.7
# 37                            TV-G    8.3
# 38                          62 min    7.1
# 39                          35 min      6
# 40                         104 min    6.8
# 41                           TV-MA    6.1
# 42                         Unrated    5.4
# 43             \nDrama               None
# 44                         109 min    6.1
# 45                          23 min      7
# 46                           PG-13    4.6
# 47                         100 min    5.8
# 48             \nDrama               None
# 49                          86 min    6.9
# 50                           TV-14    8.1
# 51                           TV-14    8.1

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-09616d73ed79> in <module>
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtypes
# Out:
# title     object
# rated     object
# rating    object
# dtype: object

# %%
df['rating'] = df['rating'].astype(float)

# %%
df_drop = df.dropna()

# %%
df_drop.head()
# Out:
#                                            title      rated  rating
# 0                               One in a Billion     69 min     6.8
# 1                                The Jungle Book     11 min     4.7
# 2  Ronny Chieng: Asian Comedian Destroys America      TV-MA     7.4
# 3                                  No Estoy Loca      TV-MA     5.5
# 4                          Live at the Foxes Den  Not Rated     4.9

# %%
df_drop
# Out:
#                                             title  \
# 0                                One in a Billion
# 1                                 The Jungle Book
# 2   Ronny Chieng: Asian Comedian Destroys America
# 3                                   No Estoy Loca
# 4                           Live at the Foxes Den
# 5                                             Amo
# 6          Anthony Jeselnik: Thoughts and Prayers
# 7                                  ¡Ay, mi madre!
# 10                            Shine On with Reese
# 11                       Revenge of the Pontianak
# 12                                       Hellions
# 13                            Pride and Prejudice
# 14                              Grandma's Wedding
# 15                                 Mujeres Arriba
# 16                                         Misfit
# 17                             My Fellow Citizens
# 18                                 Rodeo & Juliet
# 19                         The Russian Revolution
# 20                                Growing Up Wild
# 21               Trigger Warning with Killer Mike
# 22                                      Bad Blood
# 23                                       Upstarts
# 24                        Iliza: Elder Millennial
# 25                                             Mo
# 26       My Little Pony: Equestria Girls Specials
# 27                                     Der Wixxer
# 28                           Til Death Do Us Part
# 29                     Kevin Hart: Let Me Explain
# 30                       Nightworld: Door of Hell
# 31                  Cricket Fever: Mumbai Indians
# 32              Johan Falk: Organizatsija Karayan
# 33                          The Ollie & Moon Show
# 34                                   The Standups
# 36                            Historia de un clan
# 37                  Our Planet: Behind the Scenes
# 38                    Bert Kreischer: Hey Big Boy
# 39                                  Hospital Ship
# 40                         My Dear Prime Minister
# 41                              The Rachel Divide
# 42                        How Sarah Got Her Wings
# 44                      Boss Wants a Happy Ending
# 45                                   SSSS.Gridman
# 46                                         Street
# 47                                         Homies
# 49            Feminists: What Were They Thinking?
# 50                                 Rick and Morty
# 51                                 Rick and Morty
#
#                              rated  rating
# 0                           69 min     6.8
# 1                           11 min     4.7
# 2                            TV-MA     7.4
# 3                            TV-MA     5.5
# 4                        Not Rated     4.9
# 5                            TV-MA     6.4
# 6                            TV-MA     7.8
# 7                            TV-MA     3.8
# 10                          30 min     7.6
# 11                          92 min     5.2
# 12                       Not Rated     4.2
# 13    \nDrama, Romance                 7.0
# 14                          97 min     5.4
# 15                         100 min     3.6
# 16                          86 min     4.4
# 17            \nComedy                 7.1
# 18                         Unrated     4.7
# 19                           TV-14     6.6
# 20                               G     7.3
# 21                           TV-MA     6.9
# 22                       Not Rated     4.6
# 23                         112 min     6.6
# 24                           TV-MA     7.2
# 25                       Not Rated     6.5
# 26                            TV-Y     6.3
# 27                          85 min     6.2
# 28  \nSci-Fi, Thriller                 6.4
# 29                               R     6.8
# 30                           TV-MA     4.4
# 31                          40 min     7.3
# 32                          97 min     6.6
# 33                          11 min     8.2
# 34                          30 min     6.7
# 36                           TV-MA     7.7
# 37                            TV-G     8.3
# 38                          62 min     7.1
# 39                          35 min     6.0
# 40                         104 min     6.8
# 41                           TV-MA     6.1
# 42                         Unrated     5.4
# 44                         109 min     6.1
# 45                          23 min     7.0
# 46                           PG-13     4.6
# 47                         100 min     5.8
# 49                          86 min     6.9
# 50                           TV-14     8.1
# 51                           TV-14     8.1

# %%
len(df["title"].value_counts())
# Out:
# 51
